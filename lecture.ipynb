# %% [markdown]
# ## 1.	Literals, type, operations, and type conversion

# %%
type(5)
# Out:
# int

# %%
type(5.8)
# Out:
# float

# %%
type('hello world')
# Out:
# str

# %%
s = """
hello world
hello
"""

# %%
type(s)
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %%
3 + 5
# Out:
# 8

# %%
'hello' + 'world'
# Out:
# 'helloworld'

# %%
# 3 + 'hello' --> error  int + str

# %%
3 + 3.5
# Out:
# 6.5

# %%
# type conversion

int('100')
# Out:
# 100

# %%
3 + int('100')

# 3 + int('hello") --> error  str != int
# Out:
# 103

# %% [markdown]
# ## 2. Variables, dynamic typing

# %%
x = 5
x
y = x
# x and y are varivable names
y
# Out:
# 5

# %%
y = 4
y
# Out:
# 4

# %%
y + 3
# Out:
# 7

# %%
x = 'hello'

x
# Out:
# 'hello'

# %%
type(x)
# Out:
# str

# %% [markdown]
# ## 3. Expressions and operators

# %%
# arithmetic expressionx 
x = 5
x + 3, x * 3, x / 3, x % 3, x // 3
# Out:
# (8, 15, 1.6666666666666667, 2, 1)

# %%
-10 % 3
# Out:
# 2

# %%
a =  -10
b = 3

a // b, a % b
# Out:
# (-4, 2)

# %%
a == a // b * b + a % b
# Out:
# True

# %%
10 // -3
# Out:
# -4

# %%
# comperison expression

x = 5
x < 2
# Out:
# False

# %%
# logival expression
# and, or, not

x = 5
x > 2 and x < 10
# Out:
# True

# %%
not x > 5 # not false -> ture
# Out:
# True

# %%
# *, /, //, %
# +, -
# <, >, <=, >=, !=
# not
# and 
# or
# if they are in the same level, count it from left to right
