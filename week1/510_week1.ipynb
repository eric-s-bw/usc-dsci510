# %% [markdown]
# ## Literals, types, operations, and type conversion
# * literals directly represent values
# * every value is an object and every object has a type

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
5.3
# Out:
# 5.3

# %%
type(5.3) # floating-point number
# Out:
# float

# %%
89
# Out:
# 89

# %%
type("hello")
# Out:
# str

# %%
s = """
hello world
hello
"""

# %%
type(s)
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %%
3 + 5
# Out:
# 8

# %%
'hello' + 'world'
# Out:
# 'helloworld'

# %%
3 + 'hello'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_845/3545676190.py in <cell line: 0>()
# ----> 1 3 + 'hello'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
3 + 3.5
# Out:
# 6.5

# %%
# type conversion

int('100')
# Out:
# 100

# %%
3 + int('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_845/3685706343.py in <cell line: 0>()
# ----> 1 3 + int('hello')
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %% [markdown]
# ## Variables, dynamic typing
# * variables are names referring to values/objects
# * objects have types; variables are not restricted to a fixed type

# %%
x = 5
y = x
y
# x and y are variable names
y + 3
# Out:
# 8

# %%
y = 4

# %%
y
# Out:
# 4

# %%
y + 3
# Out:
# 7

# %%
x = 'hello'

# %%
# int x = 5;
# x = 10;
# x = "hello"

# Python is dynamically typed, while Java/c/c++ is statically typed

# %%
x = 5
type(x)
# Out:
# int

# %%
x = 'hello'
type(x)
# Out:
# str

# %% [markdown]
# ## Expressions and operators
# * An expression is evaluated to produce a value.
# * types of expressions:
#     * arithmetic
#     * comparison
#     * logical
#     * function call

# %% [markdown]
# ### Arithmetic expression

# %%
# +, -, *, /, //, %

x = 5
x + 3, x * 3, x / 3, x % 3 # modulo

x / 3 # true division
x // 3 # floor division

type(x/3), type(x//3)

# a//b: floor division divides and rounds down to
#  the greatest integer less than or equal to a/b
# Out:
# (float, int)

# %%
a = -10
b = 3

# identity
a == a//b * b + a % b # divisor
# Out:
# True

# %%
print(10/3, 10//3, 10%3) # 3 * 3 + 1 == 10
print(-10/-3, -10//-3, -10%-3) # 3 * -3 + -1

print(10/-3, 10//-3, 10%-3)
print(-10/3, -10//3, -10%3)
# Out:
# 3.3333333333333335 3 1
# 3.3333333333333335 3 -1
# -3.3333333333333335 -4 -2
# -3.3333333333333335 -4 2

# %%
3 * -3 + -1 == -10
# Out:
# True

# %% [markdown]
# ### Comparision expression

# %%
x = 5
x != 2
x == 5
# Out:
# True

# %% [markdown]
# ### Logical expressions

# %%
# logical expression
# and, or, not

x = 5
(x > 3) and (x < 10)
# Out:
# True

# %%
x > 5 or x < 10
# Out:
# True

# %%
not (x > 5)
# Out:
# True

# %% [markdown]
# ### Precedence of operators

# %%
# ** (right associative)
# +, - (unary) one operand
# *, /, //, % (left associative)
# +, - (left associative)
# <, >, <=, >=, !=, == (left associative)
# not
# and
# or


(((3 * (-3)) + (-1)) == (-10))

x = 8

(x > 5) or ((x < 10) and (x > 3))

(not (x > 5)) or (x < 10)

3 + (5 * 6) / 8
# Out:
# True

# %%
x = 8

(5 < x < 10) == (5 < x and x < 10)
# Out:
# True

# %%
2 ** 3 ** 4 == 2 ** (3 ** 4)
# Out:
# True

# %%
2 ** -3 == (2**-1) ** 3 == 2 ** (-3)
# Out:
# True

# %%
-2 ** 3 == -8
# Out:
# True

# %% [markdown]
# ### Function calls

# %%
r = print(x, x * 2, 'hello', 'None')
# Out:
# 8 16 hello None

# %%
def f(x):
    pass # do nothing, placeholder

r = f(5)
r

# %%
2 + 5
2 - 5
r

# %%
print(r)
# Out:
# None

# %%
len('hello')
# Out:
# 5

# %%
int('10')
# Out:
# 10

# %% [markdown]
# ## Statements
# * simple:
#     * assignment
#     * augmented assignment
#     * expression statement
#     * break
#     * continue
#     * pass
# * compound: has a number of clauses, each clause has a header and a suite
#     * conditionals
#         * if, elif, else
#     * while
#     * for
#     * with (context manager)
# * Additional compound statements:
#     * try
#     * def
#     * class
#     * match

# %% [markdown]
# ### Simple statements

# %%
x = 5
#x = x + 1
#x += 1 # augmented assignment: combining expression and assignment
x -= 1
x
# Out:
# 4

# %%
x + 5
# Out:
# 9

# %% [markdown]
# ### Conditionals

# %%
if x > 3: # header
    print('yes') # suite
    print('yes')
#elif x < 8: # header
#    print('not sure') # suite
#else: # header
#    print('no') # suite
# Out:
# yes
# yes

# %%
if x > 3: # header
    if x > 8:
        print('yes')
        3 + 5

# %%
if x > 3: print('yes')
# Out:
# yes

# %% [markdown]
# ### While loop

# %%
# while loop

v = input('enter a number: ') # prompt
type(v)
# Out:
# enter a number: 5
# str

# %%
while True:
    v = input("Please enter a command (quit to exit): ")

    if v == 'quit':
        break

    print(v)
# Out:
# Please enter a command (quit to exit): print
# print
# Please enter a command (quit to exit): exit
# exit
# Please enter a command (quit to exit): quit

# %%
i = 1

while i < 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4

# %%
v = input("Please enter a command (quit to exit): ")

while v != "quit": # sentinel
    print(v)
    v = input("Please enter a command (quit to exit): ")
# Out:
# Please enter a command (quit to exit): print
# print
# Please enter a command (quit to exit): quit

# %% [markdown]
# ### For loop

# %%
scores = [85, 97, 100, 65, 5]

# %%
type(scores)
# Out:
# list

# %%
for x in scores:
    print(x)
# Out:
# 85
# 97
# 100
# 65
# 5

# %%
sum(scores)/len(scores)
# Out:
# 70.4

# %%
total = 0
count = 0

for score in scores:
    total += score
    count += 1

print(total/count)

# exercises: finding maximum, minimum
# Out:
# 70.4

# %% [markdown]
# ### range

# %%
for x in range(1, 5, 2): # start is inclusive, stop is exclusive
    print(x)
# Out:
# 1
# 3

# %%
help(range)
# Out:
# Help on class range in module builtins:
#
# class range(object)
#  |  range(stop) -> range object
#  |  range(start, stop[, step]) -> range object
#  |
#  |  Return an object that produces a sequence of integers from start (inclusive)
#  |  to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
#  |  start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
#  |  These are exactly the valid indices for a list of 4 elements.
#  |  When step is given, it specifies the increment (or decrement).
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
# ...

# %%
range(5) # stop = 5
range(0, 5) # start = 0, stop = 5
range(0, 5, 1) # start = 0, stop = 5, step = 1
# Out:
# range(0, 5)

# %%
for x in range(5, 1, 1):
    print(x)

# x = start
# if x < 1:
#    print(x)

# or more completely
start = 5
stop = 1
step = 1

x = start
while x < stop: # note for positive step, x approaches stop from left
    print(x)
    x += step

# %%
for x in range(5, 1, -1):
    print(x)

# x = start
# if x > stop:
#   print(x) <--- 5
#   x = start + step = 5 - 1 = 4
#   ...
#   print(x)

# or more completely
start = 5
stop = 1
step = -1

x = start
while x > stop: # note for negative step, x approaching stop from right
    print(x)
    x += step
# Out:
# 5
# 4
# 3
# 2

# %%
for x in range(5, 0, -1):
    print(x)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
for x in range(5, 1, -1): # 1 is also exclusive
    print(x)

# x = 5
# if x > 1:
#   print(x)
# Out:
# 5
# 4
# 3
# 2

# %% [markdown]
# A useful rule:
# * for positive step, start < stop
# * for negative step, start > stop
#
# otherwise, range is empty

# %%
# also step can not be zero

#this will raise error
#range(1, 5, 0)

# %% [markdown]
# ### break vs continue
# * break: out of the nearest loop
# * continue: to the next iteration, i.e.,skip the remainder of the current iteration

# %%
for x in range(5):
    print('x =', x)
    for y in range(x + 1, 5):
        if y == 3:
            break
        print('\ty =', y)
# Out:
# x = 0
# 	y = 1
# 	y = 2
# x = 1
# 	y = 2
# x = 2
# x = 3
# 	y = 4
# x = 4

# %%
for x in range(1, 6):
    if x == 3:
        continue
    print(x)
# Out:
# 1
# 2
# 4
# 5

# %%
for x in range(1, 6):
    if x == 3:
        break
    print(x)
# Out:
# 1
# 2

# %% [markdown]
# ### File I/O

# %%
# %%writefile 'hello.txt'
# hello world
# hello this world
# Out:
# Overwriting hello.txt

# %%
f = open('hello.txt')

# %%
line = f.readline()
print(line)
# Out:
# hello world

# %%
line = f.readline()
print(line)
# Out:
# hello this world

# %%
line = f.readline()
print(line == '')
# Out:
# True

# %%
f.close()

# %%
with open('hello.txt') as f: # context manager
    while True:
        line = f.readline()
        print(line)
        if line == '':
            break
# Out:
# hello world
#
# hello this world

# %%
with open('hello.txt') as f: # context manager
    for line in f:
        print(line)
# Out:
# hello world
#
# hello this world
