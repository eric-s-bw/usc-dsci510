# %% [markdown]
# ## 1.	Literals, type, operations, and type conversion

# %%
type(5)
# Out:
# int

# %%
type(5.8)
# Out:
# float

# %%
type('hello world')
# Out:
# str

# %%
s = """
hello world
hello
"""

# %%
type(s)
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %%
3 + 5
# Out:
# 8

# %%
'hello' + 'world'
# Out:
# 'helloworld'

# %%
# 3 + 'hello' --> error  int + str

# %%
3 + 3.5
# Out:
# 6.5

# %%
# type conversion

int('100')
# Out:
# 100

# %%
3 + int('100')

# 3 + int('hello") --> error  str != int
# Out:
# 103

# %% [markdown]
# ## 2. Variables, dynamic typing

# %%
x = 5
x
y = x
# x and y are varivable names
y
# Out:
# 5

# %%
y = 4
y
# Out:
# 4

# %%
y + 3
# Out:
# 7

# %%
x = 'hello'

x
# Out:
# 'hello'

# %%
type(x)
# Out:
# str

# %% [markdown]
# ## 3. Expressions and operators

# %%
# arithmetic expressionx 
x = 5
x + 3, x * 3, x / 3, x % 3, x // 3
# Out:
# (8, 15, 1.6666666666666667, 2, 1)

# %%
-10 % 3
# Out:
# 2

# %%
a =  -10
b = 3

a // b, a % b
# Out:
# (-4, 2)

# %%
a == a // b * b + a % b
# Out:
# True

# %%
10 // -3
# Out:
# -4

# %%
# comperison expression

x = 5
x < 2
# Out:
# False

# %%
# logival expression
# and, or, not

x = 5
x > 2 and x < 10
# Out:
# True

# %%
not x > 5 # not false -> ture
# Out:
# True

# %%
# ** (right associative)
# +, - (unary) one operand
# *, /, //, % (left associative)
# +, - (left associative)
# <, >, <=, >=, != (left associative)
# not (unary)
# and (left associative)
# or (left associative)
# if they are in the same level, count it from left to right

# %%
x = 8

(5 < x < 10) == (5 < x) and (x < 10)
# Out:
# True

# %%
2 ** 3 ** 4 == 2 ** (3 ** 4) # right associative
# Out:
# True

# %%
2 ** -3 == (2 ** -3) ** 1 # right associative
# Out:
# True

# %%
print(x, x * 2, 'hello', 3 + 5, 3.5, True, None)
# Out:
# 8 16 hello 8 3.5 True None

# %%
len('hello')
# Out:
# 5

# %%
int('10')
# Out:
# 10

# %% [markdown]
# ## Statements
# - simple :
#   - assigniment
#   - augmented assignment
#   - expression statement
#   - break
#   - continue
#   - pass
# - compound :  has a number of clauses, each clause has a header and a suite
#   - conditionals
#     - if, elif, else
#   - while
#   - for
#   - with (context manager)

# %%
def f(x):
    pass # doing nothing, just a placeholder for a function

# %%
x = 5
# x = x + 1
# x += 1      # augmented assignment: combining expression and assignment
x -= 1
x
# Out:
# 4

# %%
x + 5
# Out:
# 9

# %%
if x > 3:  # header
    print('x is greater than 3') # suite
elif x < 8: #header
    print('x is greater than 3 and less than 8') #suite
else: #header
    print('x is less than or equal to 3') #suite
# Out:
# x is greater than 3

# %%
if x > 3:  # header
    print('x is greater than 3') # suite
# Out:
# x is greater than 3

# %%
# while loop

v  = input("Enter a value: ") # prompt

# %%
type(v)
# Out:
# str

# %%
v
# Out:
# '5'

# %%
while True:
    v = input("Enter a value: ")
    if v == 'q':
        break
    print('You entered:', v)
# Out:
# You entered: 5
# You entered: 3

# %%
i = 1

while i < 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4

# %%
scores = [85, 97, 100, 65, 5]

# %%
type(scores)
# Out:
# list

# %%
for score in scores:
    print(score)
# Out:
# 85
# 97
# 100
# 65
# 5

# %%
for x in range(5): # stop = 5, start = 0, step = 1
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1, 5, 2): # stop = 5, start = 1, step = 2
    print(i)
# Out:
# 1
# 3

# %%
for i in range(1, 5, -1):
    print(i)

# %%
# %%writefile 'hello.txt'
# hello world
# hello this world
# Out:
# Writing hello.txt

# %%
# with open('hello.txt') as f : # context manager

f = open('hello.txt') # open file for reading

# %%
line = f.readline() # read one line from the file
print(line)
# Out:
# hello world

# %%
line = f.readline() # read one line from the file
print(line)
# Out:
# hello this world

# %%
line = f.readline() # read one line from the file
print(line)

# %%
f.close() # close the file

# %%
with open('hello.txt') as f: # context manager
    for line in f:
        print(line)
# Out:
# hello world
#
# hello this world

# %%
r = print('hello world')

print(r) # print returns None
# Out:
# hello world
# None
