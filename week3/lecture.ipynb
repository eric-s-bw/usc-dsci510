# %% [markdown]
# ## Lists

# %%
# a ordered mutable sequence of data

lst = []
lst = [3, 2, 5, 1, 5, -5]
#      0, 1 ....       5 // 0 to len(lst) - 1
#     -6, -5 ....     -1  // -len(lst) to -1
#     -len(lst) to len(lst) - 1

# %% [markdown]
# ## Indexing

# %%
# index starts from zero
lst[0]

# negative index
lst[-1] # refer to last in list
lst[-2]


# lst[-7] # IndexError: list index out of range

# a valid negative index can be converted by adding len(lst) to it
# i is a negative index
# lst[-i] == lst[len(lst) - i]

lst[-1] == lst[len(lst) - 1] == lst[5]
lst[-6] == lst[len(lst) - 6] == lst[0]
# Out:
# True

# %% [markdown]
# ## Slicing

# %%
lst
# Out:
# [3, 2, 5, 1, 5, -5]

# %%
# lst[start:stop:step]

# first try
lst[0:] == lst[0:len(lst):1]

# get the first two elements of lst
lst[0:2]

lst[0:2] == lst[:2] == lst[0:2:1] # default step = 1, default start = 0

lst[:] == lst[0:len(lst)] == lst[0:len(lst):1]
# Out:
# True

# %%
# negative start/stop indices count from the end
lst[-1:] == lst[5:] # start = -1 + len(lst) = 5

lst[-2:] == lst[4:] == lst[4:6] == lst[-2:6] == lst[-2:6:1]
# Out:
# True

# %%
# slicing is flexible with (out of range) index

lst[-7:] == lst[:]

lst[-6:]

lst[-100:] == lst[-7:] == lst[-6:]
# Out:
# True

# %%
# for a negative step, default start = last in list
# default stop = pass through first in list

lst, lst[::],lst[::-1]
# Out:
# ([3, 2, 5, 1, 5, -5], [3, 2, 5, 1, 5, -5], [-5, 5, 1, 5, 2, 3])

# %%
lst[5::-1]
# Out:
# [-5, 5, 1, 5, 2, 3]

# %%
lst[:1:-1]
# Out:
# [-5, 5, 1, 5]

# %%
list(range(5, -1, -1)), lst[5:-1:-1]
# Out:
# ([5, 4, 3, 2, 1, 0], [])

# %% [markdown]
# ## identity test vs content equality test

# %%
# == testing equality of content/value
lst == lst[:] == lst[::]
lst, lst[:]
# Out:
# ([3, 2, 5, 1, 5, -5], [3, 2, 5, 1, 5, -5])

# %%
# is tests identity  slicing creates a new list
lst is lst[:], id(lst), id(lst[:])
# Out:
# (False, 4477932992, 4477776704)

# %%
x = 5
y = x

x is y, id(x), id(y) #
# Out:
# (True, 4373146088, 4373146088)

# %% [markdown]
# ## Mutablity
# - methods:
#   - insert(index, value)
#   - append (x)
#   - extend([x....])
#   - x = pop(i)
#   - remove(x)

# %%
# python list is mutable; its content may be changed
print(lst)
lst[0] = -3
print(lst)
# Out:
# [3, 2, 5, 1, 5, -5]
# [-3, 2, 5, 1, 5, -5]

# %%
# a slice can also be assigened to 
lst[1:3] = [-2, -5]

# %%
# methods
# both append and extend change the content of orignial list
#

lst.append(0)
lst
# Out:
# [-3, -2, -5, 1, 5, -5, 0]

# %%
lst.extend([10,20]) # change the content of lst
lst
# Out:
# [-3, -2, -5, 1, 5, -5, 0, 10, 20]

# %%
lst
# Out:
# [-3, -2, -5, 1, 5, -5, 0, 10, 20]

# %%
lst.insert(0, -10)
lst
# Out:
# [-10, -3, -2, -5, 1, 5, -5, 0, 10, 20]

# %%
# queue: FIFO
# stack: FILO

# queue: append (add to the end)
lst = [1, 2, 3]
lst.append(4) # into queue
x = lst.pop(0) # 1 is the first element in the list, pop(0) removes it from the list  // out of queue
x, lst
# Out:
# (1, [2, 3, 4])

# %%
y = lst.pop() # 4 is the last element in the list, pop() removes it from the list  // out of stack
y, lst
# Out:
# (4, [2, 3])

# %%
# remove the first occurrence of a value in the list
lst = [1, 2, 2, 3]
lst.remove(2)
lst
# lst.remove(4) # ValueError: list.remove(x): x not in list
# Out:
# [1, 2, 3]

# %%
# remove the second element from the list by index
del lst[1] 
lst
# Out:
# [1, 3]

# %% [markdown]
# ## Operations and built-in

# %%
lst1 = [1, 2, 3]
lst2 = [4, 5]

lst1 + lst2
# Out:
# [1, 2, 3, 4, 5]

# %%
'hello' + 'world'
# Out:
# 'helloworld'

# %%
lst1 * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
type(lst1)
# Out:
# list

# %%
lst1.__add__(lst2) # lst1 + lst2
# Out:
# [1, 2, 3, 4, 5]

# %%
lst, max(lst), min(lst), sum(lst), len(lst)
# Out:
# ([1, 3], 3, 1, 4, 2)

# %% [markdown]
# ## Common methods
# - lst.sort(): ascending/descending, in-place
# - lst.reverse(): reverse the order (ignore values), in-place
# - sorted(lst): return a new list (sorted)

# %%
lst = [3, 2, 5, 1, 5, -5] # list is a type/class
lst, type(lst)
# Out:
# ([3, 2, 5, 1, 5, -5], list)

# %%
lst.sort() # in-place 
lst
# Out:
# [-5, 1, 2, 3, 5, 5]

# %%
lst.reverse() # in-place
lst
# Out:
# [5, 5, 3, 2, 1, -5]

# %%
lst
# Out:
# [5, 5, 3, 2, 1, -5]

# %%
lst
# Out:
# [5, 5, 3, 2, 1, -5]

# %%
lst1 = sorted(lst)
lst, lst1, lst is lst1
# Out:
# ([5, 5, 3, 2, 1, -5], [-5, 1, 2, 3, 5, 5], False)

# %% [markdown]
# ## Aliasing, copying, and nested lists

# %%
lst1 = lst
lst1 is lst
# Out:
# True

# %%
lst2 = lst.copy() # shallow copying, just copy the references
lst == lst2, lst is lst2
# Out:
# (True, False)

# %%
lst3 = [[1,2,3], [4,5,6]]
lst4 = lst3.copy()

lst3 == lst4, lst3 is lst4
# Out:
# (True, False)

# %%
lst3[0], lst3[0][0]
# Out:
# ([1, 2, 3], 1)

# %%
lst3[0][0] = -1

# %%
lst3
# Out:
# [[-1, 2, 3], [4, 5, 6]]

# %%
lst4
# Out:
# [[-1, 2, 3], [4, 5, 6]]

# %%
lst3 = [[1,2,3], [4,5,6]]
lst4 = lst3.copy()

lst4[0] = [-1, -2, -3]

# %%
lst3, lst4
# Out:
# ([[1, 2, 3], [4, 5, 6]], [[-1, -2, -3], [4, 5, 6]])

# %% [markdown]
# ## Iterations

# %%
lst
# Out:
# [5, 5, 3, 2, 1, -5]

# %%
for x in lst: # lst is an iterable, iter(lst) it1 = iter(lst)
    print(x)

for x in lst: # it2 = iter(lst)
    print(x)


# it1 = iter(lst)
# it2 = iter(lst)
# it1 is it2
# Out:
# 5
# 5
# 3
# 2
# 1
# -5
# 5
# 5
# 3
# 2
# 1
# -5

# %%
for i, x in enumerate(lst): # enumerate() returns an iterable of tuples (index, value) for each element in lst
    print(i, x)
# Out:
# 0 5
# 1 5
# 2 3
# 3 2
# 4 1
# 5 -5

# %% [markdown]
# ## Pass lists to functions

# %%
lst1 = [-5, 1, 2, 3, 5, 5]

def f(lst): # list is a parameter, pass by reference
    lst[0] = -100
    # print('inside f', lst)

print(lst1) # lst1 is an argument, not passing its values
f(lst1) # not passing its values
print(lst1)
# Out:
# [-5, 1, 2, 3, 5, 5]
# [-100, 1, 2, 3, 5, 5]

# %%
for i in range(len(lst)):
    print(i, lst[i])
# Out:
# 0 5
# 1 5
# 2 3
# 3 2
# 4 1
# 5 -5

# %%
def f(a):
    global x
    x = 3

x = 5
f(x)
print(x)
# Out:
# 3

# %%
x = 5
x = 3
x
# Out:
# 3

# %% [markdown]
# ## Dictionary, tuple, set
# - dictionary: keys, values, items
# - dictionary and set are mutable
# - tuple is immutable

# %%
d = {'name': 'john', 'age' : 25}
d, type(d)
# Out:
# ({'name': 'john', 'age': 25}, dict)

# %%
d['name'], d['age']
# d['age1'] # KeyError: 'age1'
# Out:
# ('john', 25)

# %%
d.get('age1') is None
# Out:
# True

# %%
d.get('age1', 0)
# Out:
# 0

# %%
d['age'] = d['age'] + 1 # dictionary is mutable, tuple is immutable
d
# Out:
# {'name': 'john', 'age': 26}

# %%
# dictionary is also an iterable

for x in d:
    print(x)
# Out:
# name
# age

# %%
for v in d.values():
    print(v)
# Out:
# john
# 26

# %%
for k in d.keys():
    print(k)
# Out:
# name
# age

# %%
for k, v in d.items():
    print(k, v)
# Out:
# name john
# age 26

# %%
if 'name' in d:
    print('name is in d')
# Out:
# name is in d

# %%
d1 = {}

# %%
type(d1)
# Out:
# dict

# %%
d1['score'] = 5
d1
# Out:
# {'score': 5}

# %% [markdown]
# ## Tuples

# %%
# tuple is an orderd immutable sequence of objects
t = (1, 2, 3)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 1

# %%
t[-1]
# Out:
# 3

# %%
# t[0] = 5 # TypeError: 'tuple' object does not support item assignment

# %%
t = (1, 2)
x, y = t # unpacking a tuple into two variables
x, y
# Out:
# (1, 2)

# %%
t = x, y # packing a tuple from two variables
t
# Out:
# (1, 2)

# %%
x = 3
y = 5

(x, y) = (y, x) # unpacking a tuple into two variables
print(x, y)
# Out:
# 5 3

# %%
# a tuple may refer to mutable objects
t = (1, [2, 3])
t[1][0] = -2
t
# Out:
# (1, [-2, 3])

# %% [markdown]
# ## Sets

# %%
s = {1, 2, 2, 3, 2} # a collection of unique values
s
# Out:
# {1, 2, 3}

# %%
s = set()
s
# Out:
# set()

# %%
s.add(4)
s
# Out:
# {4}

# %%
# sets are not sequences
# s[0]

# %%
# set operations
# union, intersection, difference, symmetric difference 

s1 = {1, 2, 3}
s2 = {2, 3, 4}

s1.union(s2), s1.intersection(s2), s1.difference(s2), s1.symmetric_difference(s2)
# Out:
# ({1, 2, 3, 4}, {2, 3}, {1}, {1, 4})

# %%
s2 - s1, s2 & s1, s1 | s2, s1 ^ s2
# Out:
# ({4}, {2, 3}, {1, 2, 3, 4}, {1, 4})

# %%
s1, s2
# Out:
# ({1, 2, 3}, {2, 3, 4})

# %%
s3 = {1, 2, 3, 4}
s1.issubset(s3), s1.issuperset(s3), s1.isdisjoint(s3)
# Out:
# (True, False, False)

# %%
s1 < s3, s1 > s3
# Out:
# (True, False)

# %% [markdown]
# ## Iteration, generators, and exceptions
# - comprehension:

# %%
# list comprehension
lst = [x ** 2 for x in range(5)]
lst
# Out:
# [0, 1, 4, 9, 16]

# %%
lst = [x ** 2 for x in range(5) if x % 2 == 0]
lst
# Out:
# [0, 4, 16]

# %%
# dictionary comprehension

{x: x ** 2 for x in range(5)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
# set comprehension

{x % 2 for x in range(5)}
# Out:
# {0, 1}

# %%
g = (x for x in range(5))
g
# Out:
# <generator object <genexpr> at 0x10a984580>

# %%
# generator is an iterator that generates the sequence only once
# next(g) # when exhausted, raise StopIteration
# Out:
# 0

# %%
list(g)
# Out:
# [0, 1, 2, 3, 4]

# %%
# list comprehension
lst = [x ** 2 for x in range(5)]

# %%
lst
# Out:
# [0, 1, 4, 9, 16]

# %%
for x in lst:
    print(x)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
it = iter(lst) # list is an interable, it is its iterator

while True:
    try:
        x = next(it)
    except StopIteration:
        break

    print(x)
# Out:
# 0
# 1
# 4
# 9
# 16
