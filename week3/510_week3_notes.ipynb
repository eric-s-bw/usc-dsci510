# %% [markdown]
# ## Lists
# * an ordered, mutable sequence of Python objects
# * indexing & slicing
# * adding & removing elements
# * operations & builtins:
#     * +, *
#     * sum, max, min, len
# * common methods: sort, reverse, count
# * aliasing, copying, and nested lists
# * iterate over list: for, enumerate
# * passing lists to functions

# %% [markdown]
# ### Indexing

# %%
#lst = []
lst = [3, 2, 5, 1, 5, -5]

#      0  1   ...      5   // 0 to len(lst) - 1
#     -6              -1   // -len(lst) to -1

# -len(lst)  to len(lst) - 1

#len(lst)

# %%
# index starts from zero
lst[0], lst[2]
# negative index
lst[-1] # refers to last in list
lst[-2], lst[-6]

# lst[-7] # out of range
# lst[6] # IndexError: out of range
# Out:
# (5, 3)

# %%
# a valid negative index can be converted by adding the length

# -i is a negative index
# lst[-i]  == lst[len(lst) - i]

lst[-1] == lst[6 - 1] == lst[5]
lst[-6] == lst[6 - 6] == lst[0]

# %% [markdown]
# ### Slicing

# %%
lst, len(lst)
# Out:
# ([3, 2, 5, 1, 5, -5], 6)

# %%
# slicing a list produces a new list

# lst[start:stop:step]
# stop is exclusive

lst[0:] == lst[0:len(lst):1] # default step = 1, default stop is len(lst)

# get the first two elements of lst
lst[0:2] == lst[:2] == lst[0:2:1] # default step = 1, default start = 0

lst[:] == lst[0:len(lst)] == lst[0:len(lst):1]
# Out:
# True

# %%
lst[1:5] # lst[1] ... lst[4]
range(1, 5) # 1, 2, ..., 4

# %%
range(5) # 5 = stop
range(1, 5) # default step = 1
list(range(1, 5)) == list(range(1, 5, 1))
list(range(5)) == list(range(0, 5))
# Out:
# True

# %%
# negative start/stop indices count from the end
lst[-1:] == lst[5:] # start = -1 + len(lst) = -1 + 6 = 5

# how to get a list with only the last two
lst[-2:] == lst[4:] == lst[4:6] == lst[-2:6] == lst[-2:6:1]
# Out:
# True

# %%
# slicing is flexible with (out of range) index
lst[-100:] == lst[-7:] == lst[-6:]
# Out:
# True

# %%
# for a negative step, default start = last in list,
# default stop = pass through first ln list

lst, lst[::], lst[::-1]
# Out:
# ([3, 2, 5, 1, 5, -5], [3, 2, 5, 1, 5, -5], [-5, 5, 1, 5, 2, 3])

# %%
lst[5::-1], lst[5:0:-1], lst[5:-1:-1] == lst[5:5:-1]
# Out:
# ([-5, 5, 1, 5, 2, 3], [-5, 5, 1, 5, 2], True)

# %%
lst[-3:-1:] == lst[3:5:1]
# Out:
# True

# %%
lst[-3:-1:-1] == lst[3:5:-1]
# Out:
# True

# %%
lst[3:5:-1]
# Out:
# []

# %%
lst, len(lst)
# Out:
# ([3, 2, 5, 1, 5, -5], 6)

# %%
list(range(5, -1, -1)), lst[5:-1:-1]
# Out:
# ([5, 4, 3, 2, 1, 0], [])

# %%
lst
lst[::2]  == [-3, -5, 5]
# Out:
# True

# %%
# explicit negative stop vs omitted stop
lst = [1, 2, 3, 4, 5]
print(lst[5:-1:-1])   # explicit -1 → convert to index 5 → []
lst[5::-1]     # stop omitted → continue through index 0
# Out:
# []
# [5, 4, 3, 2, 1]

# %% [markdown]
# ### identity test vs content equality test

# %%
# == testing equality of content/value
lst == lst[:] == lst[::]
lst, lst[:]
# Out:
# ([3, 2, 5, 1, 5, -5], [3, 2, 5, 1, 5, -5])

# %%
# is tests identity
lst is lst[:], id(lst), id(lst[:])
# Out:
# (False, 132703565432896, 132703558013248)

# %%
lst1 = lst[:]
lst is not lst1, lst is lst1, lst == lst1
# Out:
# (True, False, True)

# %%
x = 5
y = x

x is y, id(x) == id(y)
# Out:
# (True, True)

# %% [markdown]
# ### Mutablity
# * methods:
#     * insert(i, x)
#     * append(x)
#     * extend([x...])
#     * x = pop(i)
#     * remove(x)

# %%
# python list is mutable; its content may be changed
lst = [3, 2, 5, 1, 5, -5]

print(lst)
lst[0] = -3
lst
# Out:
# [3, 2, 5, 1, 5, -5]
# [-3, 2, 5, 1, 5, -5]

# %%
# a slice can also be assigned to
#lst[1:3] == [2, 5]
lst[1:3] = [-2, -5]
lst
# Out:
# [-3, -2, -5, 1, 5, -5]

# %%
lst
# Out:
# [-3, -2, -5, 1, 5, -5]

# %%
# methods
# both append and extend change the content of orignial list
#
print(id(lst))
x = lst.append(0)
lst, x, id(lst)
# Out:
# 132703554168320
# ([-3, -2, -5, 1, 5, -5, 0, 10, 20, 0, 0], None, 132703554168320)

# %%
lst.extend([10, 20]) # change the content of lst
lst
# Out:
# [-3, -2, -5, 1, 5, -5, 0, 10, 20]

# %%
lst
# Out:
# [-3, -2, -5, 1, 5, -5, 0, 10, 20, 0, 0]

# %%
lst.insert(0, -10) # prepend
lst
# Out:
# [-10, -3, -2, -5, 1, 5, -5, 0, 10, 20, 0, 0]

# %%
lst.insert(1, 88)
lst
# Out:
# [-10, 88, -3, -2, -5, 1, 5, -5, 0, 10, 20, 0, 0]

# %%
# queue: FIFO
# stack: FILO

# queue: append (add to the end)
lst = [1, 2, 3]

# queue = append + pop(0)
lst.append(4) # into queue
x = lst.pop(0) # out of queue
x, lst
# Out:
# (1, [2, 3, 4])

# %%
# stack = append + pop()
y = lst.pop()
y
# Out:
# 4

# %%
# remove: first occurrence of value
lst = [1, 2, 2, 3]
x = lst.remove(2)

# %%
# lst.remove(4) # raise ValueError

# %%
lst
# Out:
# [1, 2, 3]

# %%
# remove the second element from the list
del lst[1]

# %%
lst.pop(1) # del lst[1]
lst
# Out:
# [1]

# %%
lst
# Out:
# [-3, 2, 5, 1, 5, -5]

# %%
x = lst.pop(-2)
x, lst
# Out:
# (5, [-3, 2, 5, 1, -5])

# %% [markdown]
# ### Operations and built-in

# %%
lst1 = [1, 2, 3]
lst2 = [4, 5]

lst1 + lst2
# Out:
# [1, 2, 3, 4, 5]

# %%
"hello" + 'world'
# Out:
# 'helloworld'

# %%
lst1 * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
3 in lst
# Out:
# False

# %%
lst
# Out:
# [1]

# %%
1 in lst
# Out:
# True

# %%
lst, max(lst), min(lst), sum(lst), len(lst)
# Out:
# ([3, 2, 5, 1, 5, -5], 5, -5, 11, 6)

# %% [markdown]
# ### Common methods
# * lst.sort(): ascending/desecnding, in-place
# * lst.reverse(): reverse the order (ignore values), in-place
# * sorted(lst): returns a new list (sorted)

# %%
lst = [3, 2, 5, 1, 5, -5]
lst, type(lst) # list is a type/class
# Out:
# ([3, 2, 5, 1, 5, -5], list)

# %%
lst.sort(reverse=True) # in-place
lst
# Out:
# [5, 5, 3, 2, 1, -5]

# %%
lst.sort()
lst
# Out:
# [-5, 1, 2, 3, 5, 5]

# %%
print(lst)
lst.reverse()
print(lst)
# Out:
# [3, 2, 5, 1, 5, -5]
# [-5, 5, 1, 5, 2, 3]

# %%
lst
# Out:
# [5, 5, 3, 2, 1, -5]

# %%
lst
# Out:
# [3, 2, 5, 1, 5, -5]

# %%
lst1 = sorted(lst)
lst, lst1, lst is lst1
# Out:
# ([3, 2, 5, 1, 5, -5], [-5, 1, 2, 3, 5, 5], False)

# %%
lst, lst.count(5)
# Out:
# ([-100, 1, 2, 3, 5, 5], 2)

# %% [markdown]
# ### Aliasing, copying, and nested lists

# %%
lst1 = lst
lst1 is lst
lst.sort()
lst1
# Out:
# [-5, 1, 2, 3, 5, 5]

# %%
lst2 = lst.copy() # shallow copying, just copy the references
lst == lst2, lst is lst2
# Out:
# (True, False)

# %%
lst3 = [[1, 2, 3], [4, 5, 6]]

# lst3 -> [ref1, ref2]
#
#          ref1 -> [1, 2, 3]
#          ref2 -> [4, 5, 6]

# lst4 -> [ref1, ref2]


lst4 = lst3.copy()

lst3 == lst4, lst3 is lst4
# Out:
# (True, False)

# %%
lst3[0], lst3[0][0]
# Out:
# ([1, 2, 3], 1)

# %%
lst3[0][0] = -1

# %%
lst3
# Out:
# [[-1, 2, 3], [4, 5, 6]]

# %%
lst4
# Out:
# [[-1, 2, 3], [4, 5, 6]]

# %%
lst3 = [[1, 2, 3], [4, 5, 6]]
lst4 = lst3.copy() # shallow copy

lst4[0] = [-1, -2, -3]

# %%
lst3
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
lst4
# Out:
# [[-1, -2, -3], [4, 5, 6]]

# %%
# lst3 -> [ref1, ref2]
#
#          ref1 -> [1, 2, 3]
#          ref2 -> [4, 5, 6]

# lst4 -> [ref1, ref2]
#          ref1 is rebound to [-1, -2, -3]
#          ref1 -> [-1, -2, -3]

# %% [markdown]
# ### Iterations

# %%
lst
# Out:
# [-5, 1, 2, 3, 5, 5]

# %%
for i in range(len(lst)):
    print(i, lst[i])
# Out:
# 0 -100
# 1 1
# 2 2
# 3 3
# 4 5
# 5 5

# %%
for x in lst: # lst is an iterable, it1 = iter(lst)
    print(x)

for x in lst: # it2 = iter(lst)
    print(x)

#it1 = iter(lst)
#it2 = iter(lst)
#it1 is it2
# Out:
# -5
# 1
# 2
# 3
# 5
# 5
# -5
# 1
# 2
# 3
# 5
# 5

# %%
for i, x in enumerate(lst): # enumerate() returns an iterable of tuples
    print(i, x)
# Out:
# 0 -5
# 1 1
# 2 2
# 3 3
# 4 5
# 5 5

# %% [markdown]
# ### Pass lists to functions

# %%
lst1 = [-5, 1, 2, 3, 5, 5]

def f(lst): # lst is a parameter
    lst[0] = -100 # this mutates lst
    # what about this?
    #lst.append(6)

print(lst1)

f(lst1) # lst = lst1 (parameter lst is bound to the same object as lst1)

print(lst1)
# Out:
# [-5, 1, 2, 3, 5, 5]
# [-100, 1, 2, 3, 5, 5, 6]

# %%
lst1 = [-5, 1, 2, 3, 5, 5]

def f(lst):
    lst = []

print(lst1)
f(lst1) # lst = lst1, then lst = [] (lst is rebound to [])
print(lst1)
# Out:
# [-5, 1, 2, 3, 5, 5]
# [-5, 1, 2, 3, 5, 5]

# %%
def f(y):
    y = 3
    print(y)

x = 5
f(x) # # y is initially bound to the same object as x;
       # then y is rebound to 3
x
# Out:
# 5

# %% [markdown]
# ## Dictionary, tuple, set
# * dictionary: keys, values, items
# * dictionary and set are mutable
# * tuple is immutable

# %%
d = {"name": 'john', 'age': 25} # {}
d, type(d)
# Out:
# ({'name': 'john', 'age': 25}, dict)

# %%
d['name']
#d['age1'] # KeyError
# Out:
# 'john'

# %%
d.get('age1') is None
# Out:
# True

# %%
d.get('age1', 0)
# Out:
# 0

# %%
d['age'] = d['age'] + 1
d
# Out:
# {'name': 'john', 'age': 26}

# %%
# dictionary is also an iterable

for x in d:
    print(x)
# Out:
# name
# age

# %%
for v in d.values():
    print(v)
# Out:
# john
# 26

# %%
for k in d.keys():
    print(k)
# Out:
# name
# age

# %%
for k, v in d.items():
    print(k, v)
# Out:
# name john
# age 26

# %%
'name' in d
# Out:
# True

# %%
# this is not required now
# note d implements __contains__
d.__contains__('name')
# Out:
# True

# %%
d1 = {}

# %%
type(d1)
# Out:
# dict

# %%
d1['score'] = 5
d1
# Out:
# {'score': 5}

# %%
26 in d.values()
# Out:
# True

# %%
values = d.values()
values
# Out:
# dict_values(['john', 26])

# %%
# this is not required now
#values does not implement __contains__
# so
#   26 in values
# falls to loop

def in_values(x, values):
    for v in values:
        if x == v:
            return True

    return False

in_values(26, values)
# Out:
# True

# %% [markdown]
# ### Tuples

# %%
# tuple is an ordered immutable sequence of objects
t = (1, 2, 3) # [1, 2, 3]

# %%
type(t)
# Out:
# tuple

# %%
t[0], t[-1]
# Out:
# (1, 3)

# %%
t[:2]
# Out:
# (1, 2)

# %%
t[::-1]
# Out:
# (3, 2, 1)

# %%
# t[0] = -1 # TypeError

# %%
t = (1, 2)
x, y = t # unpacking
x, y
# Out:
# (1, 2)

# %%
t = x, y # packing

# %%
t
# Out:
# (1, 2)

# %%
x = 3
y = 5

(x, y) = (y, x)

#z = x
#x = y
#y = z

# %%
print(x, y)
# Out:
# 5 3

# %%
# a tuple may refer to mutable objects
t = (1, [2, 3])
t[1][0] = -2

# %% [markdown]
# ### sets

# %%
s = {1, 2, 2, 3, 2} # a collection of unique values
s
# Out:
# {1, 2, 3}

# %%
s = set()
s1 = s

# %%
s.add(4)
s
# Out:
# {4}

# %%
s1
# Out:
# {4}

# %%
s1 is s
# Out:
# True

# %%
# sets are not sequences
#s[0]

# %%
# set operations
# union, intersection, difference
# |, &, -

s1 = {1, 2, 3}
s2 = {2, 3, 4}

s1.union(s2), s1.intersection(s2), s1.difference(s2), s1.symmetric_difference(s2)
# Out:
# ({1, 2, 3, 4}, {2, 3}, {1}, {1, 4})

# %%
s2 - s1, s2 & s1, s1 | s2, s1 ^ s2
# Out:
# ({4}, {2, 3}, {1, 2, 3, 4}, {1, 4})

# %%
s1, s2
# Out:
# ({1, 2, 3}, {2, 3, 4})

# %%
4 in s2, 4 not in s1
# Out:
# (True, True)

# %%
s3 = {1, 2, 3, 4}
s1.issubset(s3), s1.issuperset(s3)
# Out:
# (True, False)

# %%
s1 < s3, s1 > s3

#s1.__lt__ ~ issubset
# Out:
# <method-wrapper '__lt__' of set object at 0x7a79805950e0>

# %% [markdown]
# ## Comprehensions:
#     * list
#     * dictionary
#     * set
#     * no tuple comprehension

# %%
# list comprehension
lst = [x ** 2 for x in range(5)]

# %%
lst
# Out:
# [0, 1, 4, 9, 16]

# %%
lst = [x ** 2 for x in range(5) if x % 2 == 0]
lst
# Out:
# [0, 4, 16]

# %%
lst = []
for x in range(5):
    if x % 2 == 0:
        lst.append(x ** 2)
lst
# Out:
# [0, 4, 16]

# %%
# dictionary comprehension

{x: x**2 for x in range(5)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
d = {}

for x in range(5):
    d[x] = x**2

d
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
# set comprehension
s = {x % 2 for x in range(5)}
s
# Out:
# {0, 1}

# %% [markdown]
# ## Iterables, iterators, generators
# * iterable: an object that can provide an iterator (using iter())
#     * e.g., lst is an iterable and iter(lst) an iterator
# * iterator:
#     * represents a stream of items
#     * to get its next item, use next()
#     * note an iterator is also an iterable
#         * iter(it) is it
# * generator: a special kind of iterator generated by:
#     * generator expression: (x**2 for x in range(5))
#     * generator function: using yield

# %%
lst = [1, 2, 3, 4, 3, 2, 1]

# %%
for x in lst:
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 3
# 2
# 1

# %%
# what is behind the above for loop?

it = iter(lst) # lst is an iterable, it is its iterator

while True:
    try:
        x = next(it)
    except StopIteration:
        break

    print(x)
# Out:
# 1
# 2
# 3
# 4
# 3
# 2
# 1

# %%
iter(it) is it
# Out:
# True

# %%
# (x for x in range(5)) is a generator expression
# g1 and g2 is a generator object

# evaluating the expression ==> a generator object

g1 = (x for x in range(5))
g2 = (x for x in range(5))
g1 is g2
# Out:
# False

# %%
list(g1)
# Out:
# [0, 1, 2, 3, 4]

# %%
# generator function

# note yield lets a generator function produce a value,
# pause its execution state, and resume on the next request.
def square(n):
    for x in range(n):
        yield x ** 2

g2 = square(3)
next(g2), next(g2), next(g2)

# %% [markdown]
# ## Exceptions
# * exceptions are objects used to signal exceptional conditions during execution
# * common examples: ValueError, ZeroDivisionError, IndexError, KeyError, StopIteration

# %%
# examples
# int("abc")     # ValueError
# 10 / 0         # ZeroDivisionError
# lst[100]       # IndexError
# student["age"] # KeyError

# %%
try:
    x = int("abc")
except ValueError:
    print("Invalid integer")
# Out:
# Invalid integer

# %%
#Execution leaves the `try` block when an exception occurs
try:
    print('A')
    x = int('abc')
    print('B')
except ValueError:
    print('C')

print('D')
# Out:
# A
# C
# D

# %%
# Different exception types can have different handlers
try:
    x = int(input('x: '))
    y = int(input('y: '))
    print(x / y)
except ValueError:
    print('Invalid integer')
except ZeroDivisionError:
    print('Cannot divide by zero')
# Out:
# x: 25
# y: 0
# Cannot divide by zero

# %%
# Exceptions are objects
try:
    int('abc')
except ValueError as e:
    print(type(e))
    print(e)

    # isinstance(e, ValueError)
    # True
# Out:
# <class 'ValueError'>
# invalid literal for int() with base 10: 'abc'

# %%
# `else` runs when no exception occurs
try:
    x = int(input('Enter an integer: '))
except ValueError:
    print('Invalid input')
else:
    print('x =', x)

# %%
#`finally` runs regardless
try:
    x = int(input('Enter an integer: '))
except ValueError:
    print('Invalid input')
finally:
    print('Done')
# Out:
# Enter an integer: 25.2
# Invalid input
# Done

# %%
# `raise` explicitly signals an exception
def average(scores):
    if len(scores) == 0:
        raise ValueError('scores cannot be empty')

    return sum(scores) / len(scores)

#average([])
# ValueError

# %% [markdown]
# ## Week 3 Summary
# * Lists, tuples, dictionaries, and sets
# * Mutability, identity, aliasing, and copying
# * Comprehensions
# * Iterable vs. iterator; iter() and next()
# * Generator expressions, generator functions, yield, and lazy evaluation
# * Exceptions: try, except, else, finally, raise
